# %% [markdown]
# ## Introduction
# The idea behind this type of prediction which is more like fundamental evaluation actually since i'm not predicting future USD/RUB price directly is that DNN after analysed the most influential historical data and grasped fundamental dependencies is capable enough to accurately detect anomalies in USD/RUB  pricing. And based on Regression toward the mean phenomenon we can bet against those anomalies.  Based on my knowledge and understanding of the markets the most significant assets to influence USD/RUB price are: government bonds, repo rates, oil, and stock indexes. Let's examine those dependencies first.

# %%
import numpy as np
import pandas as pd
import time
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,BatchNormalization
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import datetime as dt
import pandas_datareader.data as web
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import norm
from scipy import stats
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline

start = dt.datetime.now()-dt.timedelta(days=15)
end = dt.datetime.now()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Read in an old dataset from csv

# %%
df_old=pd.read_csv('ML_DF_Regression.csv', nrows= 601)
df_old.set_index('Date',inplace=True)
df_old.head(1)
# Out:
#             Brent  EUR_USD  Emerging_Markets    MOEXBC  RGBITR_YIELD  \
# Date
# 2019-08-26  59.16  1.10978         39.259998  18015.13          7.16
#
#             Russia_ETF  Treas_4M  USD_RUB  USD_Repo       VOL_USD  \
# Date
# 2019-08-26   21.860001     1.933    66.07       2.1  1.282148e+11
#
#             percent_change
# Date
# 2019-08-26        0.151584

# %% [markdown]
# ## Acquiring new data from Moscow Exchange and Yahoo finance

# %%
Brent = web.get_data_moex('BRU9', start, end)
Brent.drop(['BOARDID', 'SECID', 'OPENPOSITIONVALUE', 'OPEN', 'LOW', 'HIGH', 'VALUE',  'OPENPOSITION','VOLUME'], 1, inplace=True)
Brent.index.name= 'Date'
Brent.sort_index(inplace=True) 
Brent.rename(columns={'CLOSE':'Brent'}, inplace=True)

EUR_USD = web.get_data_moex('EURUSD000TOM', start, end)
EUR_USD=EUR_USD.loc[EUR_USD.BOARDID=='CETS']
EUR_USD.drop(['BOARDID', 'SECID', 'SHORTNAME', 'VOLRUR', 'OPEN', 'LOW', 'HIGH', 'NUMTRADES',  'WAPRICE'], 1, inplace=True)
EUR_USD.index.name= 'Date'
EUR_USD.sort_index(inplace=True) 
EUR_USD.rename(columns={'CLOSE':'EUR_USD'}, inplace=True)

USD_RUB_New = web.get_data_moex('USD000UTSTOM', start, end)
USD_RUB_New=USD_RUB_New.loc[USD_RUB_New.BOARDID=='CETS']
USD_RUB_New.index.name= 'Date'
USD_RUB_New.sort_index(inplace=True) 
USD_RUB_New.rename(columns={'CLOSE':'USD_RUB','VOLRUR':'VOL_USD','LOW':'USD_LOW', 'HIGH':'USD_HIGH', 'NUMTRADES':'USD_NUMTRADES', 'OPEN':'USD_OPEN'}, inplace=True)
USD_RUB_New['percent_change']=(USD_RUB_New.USD_RUB-USD_RUB_New.USD_OPEN)/USD_RUB_New.USD_OPEN*100
USD_RUB_New.drop(['BOARDID', 'SECID', 'SHORTNAME',  'WAPRICE','USD_OPEN','USD_LOW','USD_HIGH','USD_NUMTRADES'], 1, inplace=True)

RGBITR_New= web.get_data_moex('RGBITR', start, end)
RGBITR_New.drop(['BOARDID', 'SECID', 'SHORTNAME', 'NAME', 'OPEN', 'LOW', 'HIGH','CLOSE','DECIMALS', 'CURRENCYID',  'DIVISOR','VALUE','DURATION','CAPITALIZATION'], 1, inplace=True)
RGBITR_New.index.name= 'Date'
RGBITR_New.index=pd.to_datetime(RGBITR_New.index)
RGBITR_New.rename(columns={'YIELD':'RGBITR_YIELD'}, inplace=True)
RGBITR_New.sort_index(inplace=True) 

USD_Repo = web.get_data_moex('MOEXREPOUSD', start, end)
USD_Repo.drop(['BOARDID', 'SECID', 'SHORTNAME', 'NAME', 'VALUE', 'OPEN', 'LOW', 'HIGH', 'DURATION', 'YIELD', 'DECIMALS', 'CAPITALIZATION', 'CURRENCYID', 'DIVISOR'], 1, inplace=True)
USD_Repo.rename(columns={'CLOSE':'USD_Repo'}, inplace=True)
USD_Repo.index.name= 'Date'
USD_Repo.index=pd.to_datetime(USD_Repo.index)
USD_Repo.sort_index(inplace=True) 

MOEXBC_New= web.get_data_moex('MOEXBC', start, end)
MOEXBC_New.drop(['BOARDID', 'SECID', 'SHORTNAME', 'NAME', 'OPEN', 'LOW', 'HIGH','DECIMALS', 'CURRENCYID',  'DIVISOR','VALUE','DURATION','CAPITALIZATION','YIELD'], 1, inplace=True)
MOEXBC_New.index.name= 'Date'
MOEXBC_New.index=pd.to_datetime(MOEXBC_New.index)
MOEXBC_New.rename(columns={'CLOSE':'MOEXBC'}, inplace=True)
MOEXBC_New.sort_index(inplace=True)

tickers = ['RSX','^IRX','EEM']
ETFs = pd.DataFrame()    

for ticker in tickers:
        ETF = web.get_data_yahoo(ticker, start, end)
        ETF.rename(columns={'Adj Close': ticker}, inplace=True)
        ETF.drop(['Open', 'High', 'Low', 'Close', 'Volume'], 1, inplace=True)
        if ETFs.empty:
            ETFs = ETF
        else:
            ETFs = ETFs.join(ETF, how='outer')
ETFs.rename(columns={'RSX': 'Russia_ETF', '^IRX':'Treas_4M','EEM': 'Emerging_Markets'}, inplace=True)

my_data=[Brent.Brent, EUR_USD.EUR_USD, ETFs.Emerging_Markets, MOEXBC_New.MOEXBC, RGBITR_New.RGBITR_YIELD, ETFs.Russia_ETF, ETFs.Treas_4M, USD_RUB_New.USD_RUB, USD_Repo.USD_Repo,
USD_RUB_New.VOL_USD, USD_RUB_New.percent_change]
my_data=pd.concat(my_data,axis=1)
my_data.index=pd.to_datetime(my_data.index)
my_data.dropna(inplace=True)
my_data.tail(2)
# Out:
#             Brent  EUR_USD  Emerging_Markets    MOEXBC  RGBITR_YIELD  \
# Date
# 2019-08-27   58.7  1.10898         39.330002  17973.86          7.17
# 2019-08-28   60.5  1.10745         39.439999  18106.96          7.14
#
#             Russia_ETF  Treas_4M  USD_RUB  USD_Repo       VOL_USD  \
# Date
# 2019-08-27   21.719999     1.943  66.4425      2.09  1.696794e+11
# 2019-08-28   21.870001     1.940  66.8000      2.08  1.834422e+11
#
#             percent_change
# Date
# 2019-08-27        0.464958
# 2019-08-28        0.613774

# %% [markdown]
# ## Joining old and new datasets and saving back to csv

# %%
new_df = df_old.append(my_data)
new_df.index=pd.to_datetime(new_df.index)
new_df.sort_index(ascending=False,inplace=True)
new_df.drop_duplicates(subset='MOEXBC',inplace=True)
new_df.dropna(inplace=True)
new_df.to_csv('ML_DF_Regression.csv')
new_df.head(4)
# Out:
#             Brent  EUR_USD  Emerging_Markets    MOEXBC  RGBITR_YIELD  \
# Date
# 2019-08-28  60.50  1.10745         39.439999  18106.96          7.14
# 2019-08-27  58.70  1.10898         39.330002  17973.86          7.17
# 2019-08-26  59.16  1.10978         39.259998  18015.13          7.16
# 2019-08-23  58.78  1.11348         39.049999  18058.85          7.15
#
#             Russia_ETF  Treas_4M  USD_RUB  USD_Repo       VOL_USD  \
# Date
# 2019-08-28   21.870001     1.940  66.8000      2.08  1.834422e+11
# 2019-08-27   21.719999     1.943  66.4425      2.09  1.696794e+11
# 2019-08-26   21.860001     1.933  66.0700      2.10  1.282148e+11
# 2019-08-23   21.740000     1.910  65.9850      2.11  2.163388e+11
#
#             percent_change
# Date
# 2019-08-28        0.613774
# 2019-08-27        0.464958
# 2019-08-26        0.151584
# 2019-08-23        0.556233

# %% [markdown]
# ## Read in the first 600 rows, which are in our case the latest 600 trading days or almost two and a half years.

# %%
main_df=pd.read_csv('ML_DF_Regression.csv', nrows= 600)
main_df.reset_index(drop=True,inplace=True)
main_df.head(1)
# Out:
#          Date  Brent  EUR_USD  Emerging_Markets    MOEXBC  RGBITR_YIELD  \
# 0  2019-08-28   60.5  1.10745         39.439999  18106.96          7.14
#
#    Russia_ETF  Treas_4M  USD_RUB  USD_Repo       VOL_USD  percent_change
# 0   21.870001      1.94     66.8      2.08  1.834422e+11        0.613774

# %%
main_df['USD_RUB'].describe()
# Out:
# count    600.000000
# mean      61.876842
# std        3.876225
# min       55.705000
# 25%       57.900000
# 50%       62.520000
# 75%       65.491875
# max       70.565000
# Name: USD_RUB, dtype: float64

# %%
fig = plt.figure(figsize=(10,5))
sns.distplot(main_df['USD_RUB'], fit=norm);

# %% [markdown]
# Our target USD_RUB is not normally distributed thus making prediction modeling harder. Let's explore correlations between our target and features.

# %%
corr_df= pd.DataFrame(abs(main_df.corr().USD_RUB).sort_values(ascending=False))
corr_df.rename(columns={'USD_RUB': 'corr_original'}, inplace=True)
corr_df
# Out:
#                   corr_original
# USD_RUB                1.000000
# Treas_4M               0.865236
# MOEXBC                 0.695359
# USD_Repo               0.621219
# RGBITR_YIELD           0.570114
# Brent                  0.473830
# Emerging_Markets       0.335388
# EUR_USD                0.300332
# Russia_ETF             0.125458
# percent_change         0.064846
# VOL_USD                0.019865

# %%
main_df.drop(['VOL_USD','percent_change','Emerging_Markets','EUR_USD'], 1,inplace=True)
main_df.head(1)
# Out:
#          Date  Brent    MOEXBC  RGBITR_YIELD  Russia_ETF  Treas_4M  USD_RUB  \
# 0  2019-08-28   60.5  18106.96          7.14   21.870001      1.94     66.8
#
#    USD_Repo
# 0      2.08

# %% [markdown]
# ## Train/test split

# %%
test_df=main_df.drop('Date', 1)[:80] # the latest 80 trading days
train_df = main_df.drop('Date', 1)[80:]

# %% [markdown]
# ## Feature-wise normalisation

# %%
train_targets = train_df.USD_RUB.values
train_data=train_df.drop("USD_RUB", 1).values

test_targets = test_df.USD_RUB.values
test_data=test_df.drop("USD_RUB", 1).values

mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

test_data -= mean
test_data /= std

# %%
EPOCHS =150 # how many passes through our data
BATCH_SIZE =5  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
opt='rmsprop' # set up an optimizer

NAME = f"{BATCH_SIZE}-{opt}--{test_df.drop('USD_RUB', 1).columns.tolist()}--{int(time.time())}" 

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
filepath = "regression-{epoch:02d}-{val_mean_absolute_error:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='max'))

tf.logging.set_verbosity(tf.logging.ERROR) # disable warnings

# %% [markdown]
# ## Building and training our DNN

# %%
model = Sequential()
model.add(Dense(128, activation='relu',input_shape=(train_data.shape[1],)))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(1))

model.compile(optimizer=opt, loss='mse', metrics=['mae'])

history = model.fit(
    train_data, train_targets,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(test_data, test_targets),
    callbacks=[tensorboard, checkpoint],
   )
# Out:
# Train on 520 samples, validate on 80 samples
# Epoch 1/150
# 520/520 [==============================] - 1s 2ms/sample - loss: 3673.7997 - mean_absolute_error: 60.5517 - val_loss: 3886.8064 - val_mean_absolute_error: 62.3316
# Epoch 2/150
# 520/520 [==============================] - 0s 668us/sample - loss: 3351.9841 - mean_absolute_error: 57.8330 - val_loss: 3376.8047 - val_mean_absolute_error: 58.0906
# Epoch 3/150
# 520/520 [==============================] - 0s 473us/sample - loss: 2893.5541 - mean_absolute_error: 53.6955 - val_loss: 2836.7637 - val_mean_absolute_error: 53.2363
# Epoch 4/150
# 520/520 [==============================] - 0s 473us/sample - loss: 2333.0786 - mean_absolute_error: 48.1735 - val_loss: 2054.7136 - val_mean_absolute_error: 45.2355
# Epoch 5/150
# 520/520 [==============================] - 0s 661us/sample - loss: 1719.8058 - mean_absolute_error: 41.2996 - val_loss: 1580.3369 - val_mean_absolute_error: 39.6548
# Epoch 6/150
# 520/520 [==============================] - 0s 473us/sample - loss: 1116.1739 - mean_absolute_error: 33.1113 - val_loss: 987.7276 - val_mean_absolute_error: 31.3643
# Epoch 7/150
# 520/520 [==============================] - 0s 445us/sample - loss: 582.6267 - mean_absolute_error: 23.6972 - val_loss: 428.7360 - val_mean_absolute_error: 20.5177
# Epoch 8/150
# 520/520 [==============================] - 0s 466us/sample - loss: 201.9110 - mean_absolute_error: 13.2751 - val_loss: 77.7510 - val_mean_absolute_error: 8.4890
# Epoch 9/150
# 520/520 [==============================] - 0s 460us/sample - loss: 32.1007 - mean_absolute_error: 4.6046 - val_loss: 19.4997 - val_mean_absolute_error: 3.9901
# Epoch 10/150
# 520/520 [==============================] - 0s 653us/sample - loss: 15.3817 - mean_absolute_error: 3.1130 - val_loss: 8.6697 - val_mean_absolute_error: 2.5204
# Epoch 11/150
# 520/520 [==============================] - 0s 496us/sample - loss: 17.8868 - mean_absolute_error: 3.3355 - val_loss: 3.1989 - val_mean_absolute_error: 1.4837
# Epoch 12/150
# 520/520 [==============================] - 0s 527us/sample - loss: 16.5209 - mean_absolute_error: 3.1943 - val_loss: 7.5306 - val_mean_absolute_error: 2.3275
# Epoch 13/150
# 520/520 [==============================] - 0s 464us/sample - loss: 14.2321 - mean_absolute_error: 2.9971 - val_loss: 9.0006 - val_mean_absolute_error: 2.6115
# Epoch 14/150
# 520/520 [==============================] - 0s 475us/sample - loss: 15.8031 - mean_absolute_error: 3.1573 - val_loss: 4.5126 - val_mean_absolute_error: 1.7922
# Epoch 15/150
# 520/520 [==============================] - 0s 649us/sample - loss: 15.3718 - mean_absolute_error: 3.1147 - val_loss: 6.1772 - val_mean_absolute_error: 2.3282
# Epoch 16/150
# 520/520 [==============================] - 0s 670us/sample - loss: 14.4867 - mean_absolute_error: 2.9508 - val_loss: 4.0302 - val_mean_absolute_error: 1.4307
# Epoch 17/150
# 520/520 [==============================] - 0s 597us/sample - loss: 13.7315 - mean_absolute_error: 2.9279 - val_loss: 1.5794 - val_mean_absolute_error: 0.9751
# Epoch 18/150
# 520/520 [==============================] - 0s 581us/sample - loss: 12.6520 - mean_absolute_error: 2.7976 - val_loss: 4.5882 - val_mean_absolute_error: 1.9649
# Epoch 19/150
# 520/520 [==============================] - 0s 674us/sample - loss: 11.5524 - mean_absolute_error: 2.7246 - val_loss: 4.9512 - val_mean_absolute_error: 1.8124
# Epoch 20/150
# 520/520 [==============================] - 0s 493us/sample - loss: 12.3466 - mean_absolute_error: 2.7668 - val_loss: 1.9868 - val_mean_absolute_error: 1.1572
# Epoch 21/150
# 520/520 [==============================] - 0s 479us/sample - loss: 13.5694 - mean_absolute_error: 2.8604 - val_loss: 2.2574 - val_mean_absolute_error: 1.2111
# Epoch 22/150
# 520/520 [==============================] - 0s 637us/sample - loss: 11.1295 - mean_absolute_error: 2.6252 - val_loss: 3.4553 - val_mean_absolute_error: 1.5595
# Epoch 23/150
# 520/520 [==============================] - 0s 647us/sample - loss: 10.9268 - mean_absolute_error: 2.5939 - val_loss: 5.8612 - val_mean_absolute_error: 2.1166
# Epoch 24/150
# 520/520 [==============================] - 0s 651us/sample - loss: 10.8357 - mean_absolute_error: 2.6261 - val_loss: 1.5484 - val_mean_absolute_error: 1.0566
# Epoch 25/150
# 520/520 [==============================] - 0s 535us/sample - loss: 11.7114 - mean_absolute_error: 2.6926 - val_loss: 2.0824 - val_mean_absolute_error: 1.1972
# Epoch 26/150
# 520/520 [==============================] - 0s 475us/sample - loss: 9.0277 - mean_absolute_error: 2.3428 - val_loss: 3.1971 - val_mean_absolute_error: 1.4293
# Epoch 27/150
# 520/520 [==============================] - 0s 470us/sample - loss: 10.1249 - mean_absolute_error: 2.5282 - val_loss: 4.5665 - val_mean_absolute_error: 1.7009
# Epoch 28/150
# 520/520 [==============================] - 0s 628us/sample - loss: 9.0999 - mean_absolute_error: 2.4253 - val_loss: 5.2039 - val_mean_absolute_error: 1.9694
# Epoch 29/150
# 520/520 [==============================] - 0s 493us/sample - loss: 10.4424 - mean_absolute_error: 2.5599 - val_loss: 2.8448 - val_mean_absolute_error: 1.4306
# Epoch 30/150
# 520/520 [==============================] - 0s 472us/sample - loss: 9.1829 - mean_absolute_error: 2.4204 - val_loss: 11.5829 - val_mean_absolute_error: 3.0386
# Epoch 31/150
# 520/520 [==============================] - 0s 525us/sample - loss: 9.7593 - mean_absolute_error: 2.4863 - val_loss: 4.3467 - val_mean_absolute_error: 1.8146
# Epoch 32/150
# 520/520 [==============================] - 0s 591us/sample - loss: 8.5077 - mean_absolute_error: 2.2857 - val_loss: 13.9041 - val_mean_absolute_error: 3.2942
# Epoch 33/150
# 520/520 [==============================] - 0s 666us/sample - loss: 7.9759 - mean_absolute_error: 2.2547 - val_loss: 6.8013 - val_mean_absolute_error: 2.2090
# Epoch 34/150
# 520/520 [==============================] - 0s 506us/sample - loss: 8.2043 - mean_absolute_error: 2.2423 - val_loss: 14.8446 - val_mean_absolute_error: 3.3775
# Epoch 35/150
# 520/520 [==============================] - 0s 506us/sample - loss: 7.9440 - mean_absolute_error: 2.2397 - val_loss: 8.2601 - val_mean_absolute_error: 2.4881
# Epoch 36/150
# 520/520 [==============================] - 0s 531us/sample - loss: 7.3548 - mean_absolute_error: 2.1355 - val_loss: 5.9010 - val_mean_absolute_error: 2.0736
# Epoch 37/150
# 520/520 [==============================] - 0s 629us/sample - loss: 7.5994 - mean_absolute_error: 2.1749 - val_loss: 3.7444 - val_mean_absolute_error: 1.7890
# Epoch 38/150
# 520/520 [==============================] - 0s 512us/sample - loss: 7.6370 - mean_absolute_error: 2.1469 - val_loss: 1.6208 - val_mean_absolute_error: 1.1672
# Epoch 39/150
# 520/520 [==============================] - 0s 462us/sample - loss: 8.0585 - mean_absolute_error: 2.2661 - val_loss: 5.1425 - val_mean_absolute_error: 2.0143
# Epoch 40/150
# 520/520 [==============================] - 0s 514us/sample - loss: 7.3037 - mean_absolute_error: 2.0869 - val_loss: 4.2187 - val_mean_absolute_error: 1.9564
# Epoch 41/150
# 520/520 [==============================] - 0s 599us/sample - loss: 7.1427 - mean_absolute_error: 2.0767 - val_loss: 2.1698 - val_mean_absolute_error: 1.3585
# Epoch 42/150
# 520/520 [==============================] - 0s 566us/sample - loss: 7.5188 - mean_absolute_error: 2.2009 - val_loss: 5.1068 - val_mean_absolute_error: 1.9675
# Epoch 43/150
# 520/520 [==============================] - 0s 527us/sample - loss: 5.9737 - mean_absolute_error: 1.9251 - val_loss: 4.0326 - val_mean_absolute_error: 1.7003
# Epoch 44/150
# 520/520 [==============================] - 0s 548us/sample - loss: 6.8908 - mean_absolute_error: 2.0733 - val_loss: 4.4874 - val_mean_absolute_error: 1.8359
# Epoch 45/150
# 520/520 [==============================] - 0s 556us/sample - loss: 6.6244 - mean_absolute_error: 1.9959 - val_loss: 2.0027 - val_mean_absolute_error: 1.3044
# Epoch 46/150
# 520/520 [==============================] - 0s 576us/sample - loss: 6.3124 - mean_absolute_error: 1.9903 - val_loss: 3.0957 - val_mean_absolute_error: 1.5153
# Epoch 47/150
# 520/520 [==============================] - 0s 599us/sample - loss: 5.5212 - mean_absolute_error: 1.8659 - val_loss: 3.8477 - val_mean_absolute_error: 1.7114
# Epoch 48/150
# 520/520 [==============================] - 0s 541us/sample - loss: 6.9532 - mean_absolute_error: 2.0857 - val_loss: 9.7502 - val_mean_absolute_error: 2.7105
# Epoch 49/150
# 520/520 [==============================] - 0s 450us/sample - loss: 6.1815 - mean_absolute_error: 1.9674 - val_loss: 6.9122 - val_mean_absolute_error: 2.1865
# Epoch 50/150
# 520/520 [==============================] - 0s 475us/sample - loss: 6.4905 - mean_absolute_error: 2.0229 - val_loss: 5.7931 - val_mean_absolute_error: 2.0442
# Epoch 51/150
# 520/520 [==============================] - 0s 470us/sample - loss: 5.9335 - mean_absolute_error: 1.9203 - val_loss: 3.8444 - val_mean_absolute_error: 1.7477
# Epoch 52/150
# 520/520 [==============================] - ETA: 0s - loss: 6.6877 - mean_absolute_error: 2.092 - 0s 445us/sample - loss: 6.4719 - mean_absolute_error: 2.0625 - val_loss: 0.8368 - val_mean_absolute_error: 0.8153
# Epoch 53/150
# 520/520 [==============================] - 0s 441us/sample - loss: 6.1958 - mean_absolute_error: 1.9863 - val_loss: 2.6800 - val_mean_absolute_error: 1.4377
# Epoch 54/150
# 520/520 [==============================] - 0s 458us/sample - loss: 6.1661 - mean_absolute_error: 1.9674 - val_loss: 3.5450 - val_mean_absolute_error: 1.5954
# Epoch 55/150
# 520/520 [==============================] - 0s 485us/sample - loss: 5.6070 - mean_absolute_error: 1.8643 - val_loss: 10.0676 - val_mean_absolute_error: 2.7374
# Epoch 56/150
# 520/520 [==============================] - 0s 446us/sample - loss: 5.2016 - mean_absolute_error: 1.8284 - val_loss: 4.3238 - val_mean_absolute_error: 1.8912
# Epoch 57/150
# 520/520 [==============================] - 0s 473us/sample - loss: 5.5138 - mean_absolute_error: 1.8418 - val_loss: 4.3821 - val_mean_absolute_error: 1.8260
# Epoch 58/150
# 520/520 [==============================] - ETA: 0s - loss: 4.7719 - mean_absolute_error: 1.704 - 0s 539us/sample - loss: 4.8688 - mean_absolute_error: 1.7101 - val_loss: 10.6150 - val_mean_absolute_error: 2.8208
# Epoch 59/150
# 520/520 [==============================] - 0s 537us/sample - loss: 4.6854 - mean_absolute_error: 1.7383 - val_loss: 5.5231 - val_mean_absolute_error: 2.0629
# Epoch 60/150
# 520/520 [==============================] - 0s 468us/sample - loss: 5.2600 - mean_absolute_error: 1.7940 - val_loss: 7.5071 - val_mean_absolute_error: 2.4296
# Epoch 61/150
# 520/520 [==============================] - 0s 597us/sample - loss: 4.2358 - mean_absolute_error: 1.6445 - val_loss: 7.4062 - val_mean_absolute_error: 2.2952
# Epoch 62/150
# 520/520 [==============================] - 0s 579us/sample - loss: 5.6738 - mean_absolute_error: 1.9868 - val_loss: 8.4288 - val_mean_absolute_error: 2.5705
# Epoch 63/150
# 520/520 [==============================] - 0s 462us/sample - loss: 4.8309 - mean_absolute_error: 1.7360 - val_loss: 9.1297 - val_mean_absolute_error: 2.6039
# Epoch 64/150
# 520/520 [==============================] - 0s 454us/sample - loss: 5.2404 - mean_absolute_error: 1.8411 - val_loss: 4.1120 - val_mean_absolute_error: 1.8009
# Epoch 65/150
# 520/520 [==============================] - 0s 581us/sample - loss: 5.0757 - mean_absolute_error: 1.7907 - val_loss: 4.9244 - val_mean_absolute_error: 1.9508
# Epoch 66/150
# 520/520 [==============================] - 0s 547us/sample - loss: 4.5478 - mean_absolute_error: 1.7296 - val_loss: 7.7028 - val_mean_absolute_error: 2.3360
# Epoch 67/150
# 520/520 [==============================] - 0s 566us/sample - loss: 4.8732 - mean_absolute_error: 1.7461 - val_loss: 4.9941 - val_mean_absolute_error: 2.0052
# Epoch 68/150
# 520/520 [==============================] - 0s 460us/sample - loss: 5.2242 - mean_absolute_error: 1.8092 - val_loss: 5.8726 - val_mean_absolute_error: 2.0984
# Epoch 69/150
# 520/520 [==============================] - 0s 470us/sample - loss: 4.5218 - mean_absolute_error: 1.7044 - val_loss: 6.2102 - val_mean_absolute_error: 2.1129
# Epoch 70/150
# 520/520 [==============================] - 0s 606us/sample - loss: 5.3008 - mean_absolute_error: 1.8276 - val_loss: 6.1784 - val_mean_absolute_error: 2.2169
# Epoch 71/150
# 520/520 [==============================] - 0s 522us/sample - loss: 4.4783 - mean_absolute_error: 1.6778 - val_loss: 8.2289 - val_mean_absolute_error: 2.4292
# Epoch 72/150
# 520/520 [==============================] - 0s 483us/sample - loss: 4.2962 - mean_absolute_error: 1.6357 - val_loss: 8.8981 - val_mean_absolute_error: 2.5379
# Epoch 73/150
# 520/520 [==============================] - 0s 556us/sample - loss: 4.7337 - mean_absolute_error: 1.7358 - val_loss: 7.9134 - val_mean_absolute_error: 2.4867
# Epoch 74/150
# 520/520 [==============================] - 0s 539us/sample - loss: 4.0093 - mean_absolute_error: 1.6138 - val_loss: 7.5489 - val_mean_absolute_error: 2.4374
# Epoch 75/150
# 520/520 [==============================] - 0s 537us/sample - loss: 4.0634 - mean_absolute_error: 1.5679 - val_loss: 7.9266 - val_mean_absolute_error: 2.4225
# Epoch 76/150
# 520/520 [==============================] - 0s 572us/sample - loss: 4.8077 - mean_absolute_error: 1.7565 - val_loss: 5.6295 - val_mean_absolute_error: 2.0060
# Epoch 77/150
# 520/520 [==============================] - 0s 464us/sample - loss: 3.4902 - mean_absolute_error: 1.4631 - val_loss: 4.9440 - val_mean_absolute_error: 1.9887
# Epoch 78/150
# 520/520 [==============================] - 0s 502us/sample - loss: 5.0632 - mean_absolute_error: 1.8051 - val_loss: 7.0358 - val_mean_absolute_error: 2.2344
# Epoch 79/150
# 520/520 [==============================] - 0s 450us/sample - loss: 3.8901 - mean_absolute_error: 1.5578 - val_loss: 5.5664 - val_mean_absolute_error: 2.0178
# Epoch 80/150
# 520/520 [==============================] - 0s 462us/sample - loss: 4.5287 - mean_absolute_error: 1.7270 - val_loss: 8.7903 - val_mean_absolute_error: 2.5019
# Epoch 81/150
# 520/520 [==============================] - 0s 564us/sample - loss: 4.0311 - mean_absolute_error: 1.5995 - val_loss: 10.7568 - val_mean_absolute_error: 2.8422
# Epoch 82/150
# 520/520 [==============================] - 0s 477us/sample - loss: 4.0489 - mean_absolute_error: 1.6019 - val_loss: 6.2244 - val_mean_absolute_error: 2.1370
# Epoch 83/150
# 520/520 [==============================] - 0s 471us/sample - loss: 3.6048 - mean_absolute_error: 1.5125 - val_loss: 10.2799 - val_mean_absolute_error: 2.7658
# Epoch 84/150
# 520/520 [==============================] - 0s 520us/sample - loss: 4.5133 - mean_absolute_error: 1.6850 - val_loss: 3.6074 - val_mean_absolute_error: 1.7184
# Epoch 85/150
# 520/520 [==============================] - 0s 471us/sample - loss: 3.8720 - mean_absolute_error: 1.5519 - val_loss: 5.7452 - val_mean_absolute_error: 2.1988
# Epoch 86/150
# 520/520 [==============================] - 0s 462us/sample - loss: 4.2956 - mean_absolute_error: 1.6726 - val_loss: 7.1617 - val_mean_absolute_error: 2.2874
# Epoch 87/150
# 520/520 [==============================] - 0s 485us/sample - loss: 3.9183 - mean_absolute_error: 1.6244 - val_loss: 4.8438 - val_mean_absolute_error: 1.9286
# Epoch 88/150
# 520/520 [==============================] - 0s 597us/sample - loss: 4.4753 - mean_absolute_error: 1.7238 - val_loss: 6.2465 - val_mean_absolute_error: 2.1248
# Epoch 89/150
# 520/520 [==============================] - 0s 479us/sample - loss: 4.1598 - mean_absolute_error: 1.6386 - val_loss: 9.6582 - val_mean_absolute_error: 2.6327
# Epoch 90/150
# 520/520 [==============================] - 0s 541us/sample - loss: 3.8050 - mean_absolute_error: 1.5396 - val_loss: 6.0577 - val_mean_absolute_error: 2.1626
# Epoch 91/150
# 520/520 [==============================] - 0s 412us/sample - loss: 4.3082 - mean_absolute_error: 1.6238 - val_loss: 4.2518 - val_mean_absolute_error: 1.8308
# Epoch 92/150
# 520/520 [==============================] - 0s 414us/sample - loss: 4.3535 - mean_absolute_error: 1.6934 - val_loss: 5.1841 - val_mean_absolute_error: 1.9448
# Epoch 93/150
# 520/520 [==============================] - 0s 423us/sample - loss: 4.1188 - mean_absolute_error: 1.6085 - val_loss: 4.9597 - val_mean_absolute_error: 1.8735
# Epoch 94/150
# 520/520 [==============================] - 0s 445us/sample - loss: 4.2110 - mean_absolute_error: 1.6229 - val_loss: 5.3269 - val_mean_absolute_error: 1.9775
# Epoch 95/150
# 520/520 [==============================] - 0s 448us/sample - loss: 3.4145 - mean_absolute_error: 1.4890 - val_loss: 7.0281 - val_mean_absolute_error: 2.2582
# Epoch 96/150
# 520/520 [==============================] - 0s 429us/sample - loss: 4.0592 - mean_absolute_error: 1.6502 - val_loss: 4.8764 - val_mean_absolute_error: 1.9283
# Epoch 97/150
# 520/520 [==============================] - 0s 425us/sample - loss: 4.7240 - mean_absolute_error: 1.7838 - val_loss: 6.6981 - val_mean_absolute_error: 2.2489
# Epoch 98/150
# 520/520 [==============================] - 0s 429us/sample - loss: 4.6424 - mean_absolute_error: 1.7585 - val_loss: 4.5532 - val_mean_absolute_error: 1.8132
# Epoch 99/150
# 520/520 [==============================] - 0s 552us/sample - loss: 4.1681 - mean_absolute_error: 1.6369 - val_loss: 3.9404 - val_mean_absolute_error: 1.6805
# Epoch 100/150
# 520/520 [==============================] - 0s 609us/sample - loss: 3.8281 - mean_absolute_error: 1.5921 - val_loss: 3.6693 - val_mean_absolute_error: 1.6603
# Epoch 101/150
# 520/520 [==============================] - 0s 473us/sample - loss: 3.9595 - mean_absolute_error: 1.6512 - val_loss: 3.1785 - val_mean_absolute_error: 1.5190
# Epoch 102/150
# 520/520 [==============================] - 0s 483us/sample - loss: 3.4490 - mean_absolute_error: 1.4762 - val_loss: 2.0061 - val_mean_absolute_error: 1.3173
# Epoch 103/150
# 520/520 [==============================] - 0s 445us/sample - loss: 3.9383 - mean_absolute_error: 1.5363 - val_loss: 4.6096 - val_mean_absolute_error: 1.8376
# Epoch 104/150
# 520/520 [==============================] - 0s 410us/sample - loss: 4.0493 - mean_absolute_error: 1.6144 - val_loss: 3.5977 - val_mean_absolute_error: 1.6819
# Epoch 105/150
# 520/520 [==============================] - 0s 408us/sample - loss: 3.6872 - mean_absolute_error: 1.5159 - val_loss: 8.9362 - val_mean_absolute_error: 2.5883
# Epoch 106/150
# 520/520 [==============================] - 0s 404us/sample - loss: 3.6568 - mean_absolute_error: 1.4869 - val_loss: 3.7913 - val_mean_absolute_error: 1.7457
# Epoch 107/150
# 520/520 [==============================] - 0s 429us/sample - loss: 3.6259 - mean_absolute_error: 1.4851 - val_loss: 5.3925 - val_mean_absolute_error: 1.9975
# Epoch 108/150
# 520/520 [==============================] - 0s 423us/sample - loss: 3.5740 - mean_absolute_error: 1.5215 - val_loss: 5.3087 - val_mean_absolute_error: 1.9814
# Epoch 109/150
# 520/520 [==============================] - 0s 504us/sample - loss: 3.3115 - mean_absolute_error: 1.4223 - val_loss: 5.6494 - val_mean_absolute_error: 2.0843
# Epoch 110/150
# 520/520 [==============================] - 0s 435us/sample - loss: 3.8390 - mean_absolute_error: 1.5547 - val_loss: 6.4673 - val_mean_absolute_error: 2.2032
# Epoch 111/150
# 520/520 [==============================] - 0s 431us/sample - loss: 3.9836 - mean_absolute_error: 1.6299 - val_loss: 6.2711 - val_mean_absolute_error: 2.1609
# Epoch 112/150
# 520/520 [==============================] - 0s 422us/sample - loss: 3.8518 - mean_absolute_error: 1.5700 - val_loss: 6.9647 - val_mean_absolute_error: 2.2841
# Epoch 113/150
# 520/520 [==============================] - 0s 412us/sample - loss: 3.7432 - mean_absolute_error: 1.4914 - val_loss: 3.9647 - val_mean_absolute_error: 1.7844
# Epoch 114/150
# 520/520 [==============================] - 0s 387us/sample - loss: 4.0060 - mean_absolute_error: 1.5906 - val_loss: 2.6927 - val_mean_absolute_error: 1.5541
# Epoch 115/150
# 520/520 [==============================] - 0s 381us/sample - loss: 3.8790 - mean_absolute_error: 1.6101 - val_loss: 2.7772 - val_mean_absolute_error: 1.4290
# Epoch 116/150
# 520/520 [==============================] - 0s 422us/sample - loss: 4.1010 - mean_absolute_error: 1.5801 - val_loss: 3.5911 - val_mean_absolute_error: 1.6634
# Epoch 117/150
# 520/520 [==============================] - 0s 412us/sample - loss: 3.1730 - mean_absolute_error: 1.4108 - val_loss: 4.8590 - val_mean_absolute_error: 1.9415
# Epoch 118/150
# 520/520 [==============================] - 0s 437us/sample - loss: 4.0097 - mean_absolute_error: 1.6061 - val_loss: 5.2190 - val_mean_absolute_error: 1.9496
# Epoch 119/150
# 520/520 [==============================] - 0s 398us/sample - loss: 4.1036 - mean_absolute_error: 1.5762 - val_loss: 3.7015 - val_mean_absolute_error: 1.7017
# Epoch 120/150
# 520/520 [==============================] - 0s 391us/sample - loss: 3.9396 - mean_absolute_error: 1.5657 - val_loss: 1.5778 - val_mean_absolute_error: 1.1521
# Epoch 121/150
# 520/520 [==============================] - 0s 421us/sample - loss: 3.7284 - mean_absolute_error: 1.5023 - val_loss: 1.9459 - val_mean_absolute_error: 1.2602
# Epoch 122/150
# 520/520 [==============================] - 0s 379us/sample - loss: 3.4598 - mean_absolute_error: 1.4832 - val_loss: 2.4339 - val_mean_absolute_error: 1.3548
# Epoch 123/150
# 520/520 [==============================] - 0s 632us/sample - loss: 3.8662 - mean_absolute_error: 1.5391 - val_loss: 2.1763 - val_mean_absolute_error: 1.3074
# Epoch 124/150
# 520/520 [==============================] - 0s 420us/sample - loss: 3.5476 - mean_absolute_error: 1.5144 - val_loss: 1.4268 - val_mean_absolute_error: 1.1093
# Epoch 125/150
# 520/520 [==============================] - 0s 441us/sample - loss: 3.7796 - mean_absolute_error: 1.5750 - val_loss: 2.8450 - val_mean_absolute_error: 1.4652
# Epoch 126/150
# 520/520 [==============================] - 0s 418us/sample - loss: 3.7215 - mean_absolute_error: 1.5972 - val_loss: 4.6893 - val_mean_absolute_error: 1.8360
# Epoch 127/150
# 520/520 [==============================] - 0s 398us/sample - loss: 3.8176 - mean_absolute_error: 1.5114 - val_loss: 3.5854 - val_mean_absolute_error: 1.5966
# Epoch 128/150
# 520/520 [==============================] - 0s 423us/sample - loss: 3.7226 - mean_absolute_error: 1.5205 - val_loss: 2.8234 - val_mean_absolute_error: 1.4179
# Epoch 129/150
# 520/520 [==============================] - 0s 448us/sample - loss: 4.1040 - mean_absolute_error: 1.6056 - val_loss: 3.3988 - val_mean_absolute_error: 1.5945
# Epoch 130/150
# 520/520 [==============================] - 0s 402us/sample - loss: 3.2642 - mean_absolute_error: 1.3891 - val_loss: 3.3867 - val_mean_absolute_error: 1.5836
# Epoch 131/150
# 520/520 [==============================] - 0s 450us/sample - loss: 3.2908 - mean_absolute_error: 1.4479 - val_loss: 2.1217 - val_mean_absolute_error: 1.3382
# Epoch 132/150
# 520/520 [==============================] - 0s 427us/sample - loss: 3.9114 - mean_absolute_error: 1.5812 - val_loss: 1.9315 - val_mean_absolute_error: 1.2633
# Epoch 133/150
# 520/520 [==============================] - 0s 506us/sample - loss: 4.6660 - mean_absolute_error: 1.7682 - val_loss: 3.3773 - val_mean_absolute_error: 1.5696
# Epoch 134/150
# 520/520 [==============================] - 0s 421us/sample - loss: 4.1662 - mean_absolute_error: 1.6758 - val_loss: 2.2245 - val_mean_absolute_error: 1.3520
# Epoch 135/150
# 520/520 [==============================] - 0s 423us/sample - loss: 3.2278 - mean_absolute_error: 1.4436 - val_loss: 3.2647 - val_mean_absolute_error: 1.5715
# Epoch 136/150
# 520/520 [==============================] - 0s 425us/sample - loss: 3.7541 - mean_absolute_error: 1.5449 - val_loss: 2.8343 - val_mean_absolute_error: 1.5242
# Epoch 137/150
# 520/520 [==============================] - 0s 414us/sample - loss: 3.7991 - mean_absolute_error: 1.5159 - val_loss: 1.3396 - val_mean_absolute_error: 1.0484
# Epoch 138/150
# 520/520 [==============================] - 0s 396us/sample - loss: 3.2686 - mean_absolute_error: 1.4276 - val_loss: 3.7620 - val_mean_absolute_error: 1.7084
# Epoch 139/150
# 520/520 [==============================] - 0s 587us/sample - loss: 3.9951 - mean_absolute_error: 1.5486 - val_loss: 3.2089 - val_mean_absolute_error: 1.6307
# Epoch 140/150
# 520/520 [==============================] - 0s 683us/sample - loss: 3.7642 - mean_absolute_error: 1.6014 - val_loss: 4.3329 - val_mean_absolute_error: 1.7791
# Epoch 141/150
# 520/520 [==============================] - 0s 502us/sample - loss: 3.8599 - mean_absolute_error: 1.5615 - val_loss: 1.9169 - val_mean_absolute_error: 1.2700
# Epoch 142/150
# 520/520 [==============================] - 0s 483us/sample - loss: 2.9755 - mean_absolute_error: 1.3788 - val_loss: 2.5807 - val_mean_absolute_error: 1.4062
# Epoch 143/150
# 520/520 [==============================] - 0s 477us/sample - loss: 3.5064 - mean_absolute_error: 1.4781 - val_loss: 2.4940 - val_mean_absolute_error: 1.3899
# Epoch 144/150
# 520/520 [==============================] - 0s 437us/sample - loss: 4.1099 - mean_absolute_error: 1.6160 - val_loss: 2.0059 - val_mean_absolute_error: 1.2511
# Epoch 145/150
# 520/520 [==============================] - 0s 684us/sample - loss: 4.2622 - mean_absolute_error: 1.6740 - val_loss: 1.1704 - val_mean_absolute_error: 0.9862
# Epoch 146/150
# 520/520 [==============================] - 0s 518us/sample - loss: 3.6890 - mean_absolute_error: 1.5272 - val_loss: 1.2707 - val_mean_absolute_error: 1.0005
# Epoch 147/150
# 520/520 [==============================] - 0s 537us/sample - loss: 2.7603 - mean_absolute_error: 1.3015 - val_loss: 0.8199 - val_mean_absolute_error: 0.7921
# Epoch 148/150
# 520/520 [==============================] - 0s 473us/sample - loss: 3.6595 - mean_absolute_error: 1.5139 - val_loss: 1.7143 - val_mean_absolute_error: 1.1335
# Epoch 149/150
# 520/520 [==============================] - 0s 473us/sample - loss: 3.3231 - mean_absolute_error: 1.4938 - val_loss: 1.4740 - val_mean_absolute_error: 1.0968
# Epoch 150/150
# 520/520 [==============================] - 0s 545us/sample - loss: 3.6056 - mean_absolute_error: 1.5435 - val_loss: 1.9265 - val_mean_absolute_error: 1.1920

# %% [markdown]
# Our validation metric to monitor during training is mae (Mean Absolute Error). It is simply the absolute value of the difference between the predictions and the targets.

# %% [markdown]
# ## TensorBoard charts of the different features combinations tested

# %% [markdown]
# ![alt text](111.jpg)

# %% [markdown]
# And the best result which is the lowest mean absolute error belongs to (Brent, MOEXBC, RGBITR_YIELD, Russia_ETF, Treas_4M, USD_Repo) set of features.

# %% [markdown]
# ## Let's examine our features and get rid of outliers

# %%
main_df=pd.read_csv('ML_DF_Regression.csv', nrows= 600)
main_df.reset_index(drop=True,inplace=True)
main_df.head(1)
# Out:
#          Date  Brent  EUR_USD  Emerging_Markets    MOEXBC  RGBITR_YIELD  \
# 0  2019-08-28   60.5  1.10745         39.439999  18106.96          7.14
#
#    Russia_ETF  Treas_4M  USD_RUB  USD_Repo       VOL_USD  percent_change
# 0   21.870001      1.94     66.8      2.08  1.834422e+11        0.613774

# %%
var = 'percent_change'
data = pd.concat([main_df['USD_RUB'], main_df[var]], axis=1)
data.plot.scatter(x=var, y='USD_RUB', ylim=(54,71));

# %%
main_df.drop(main_df.loc[(main_df.percent_change > 3) + (main_df.percent_change <-2)].index, axis=0, inplace=True)

# %%
var = 'Treas_4M'
data = pd.concat([main_df['USD_RUB'], main_df[var]], axis=1)
data.plot.scatter(x=var, y='USD_RUB', ylim=(54,71));

# %%
var = 'MOEXBC'
data = pd.concat([main_df['USD_RUB'], main_df[var]], axis=1)
data.plot.scatter(x=var, y='USD_RUB', ylim=(54,71));

# %%
var = 'USD_Repo'
data = pd.concat([main_df['USD_RUB'], main_df[var]], axis=1)
data.plot.scatter(x=var, y='USD_RUB', ylim=(54,71));

# %%
main_df.drop(main_df.loc[((main_df.USD_RUB > 66) & (main_df.USD_Repo <2)) + ((main_df.USD_RUB < 58) & (main_df.USD_Repo >3))].index, axis=0, inplace=True)

# %%
var = 'RGBITR_YIELD'
data = pd.concat([main_df['USD_RUB'], main_df[var]], axis=1)
data.plot.scatter(x=var, y='USD_RUB', ylim=(54,71));

# %%
main_df.drop(main_df.loc[(main_df.RGBITR_YIELD > 8.9)].index, axis=0, inplace=True)

# %%
var = 'Brent'
data = pd.concat([main_df['USD_RUB'], main_df[var]], axis=1)
data.plot.scatter(x=var, y='USD_RUB', ylim=(54,71));

# %%
main_df['USD_RUB'].describe()
# Out:
# count    585.000000
# mean      61.828073
# std        3.831352
# min       55.847500
# 25%       57.900000
# 50%       62.502500
# 75%       65.437500
# max       69.560000
# Name: USD_RUB, dtype: float64

# %%
corr_new = abs(main_df.corr().USD_RUB).sort_values(ascending=False)
corr_df['corr_new']=corr_new
corr_df
# Out:
#                   corr_original  corr_new
# USD_RUB                1.000000  1.000000
# Treas_4M               0.865236  0.869337
# MOEXBC                 0.695359  0.703650
# USD_Repo               0.621219  0.659734
# RGBITR_YIELD           0.570114  0.551114
# Brent                  0.473830  0.480552
# Emerging_Markets       0.335388  0.319814
# EUR_USD                0.300332  0.298211
# Russia_ETF             0.125458  0.153380
# percent_change         0.064846  0.066026
# VOL_USD                0.019865  0.029323

# %%
main_df.set_index('Date',inplace=True)
main_df.to_csv('main_df_cleared.csv') # Save cleaned dataset just in case

# %% [markdown]
# ## Feature Engineering

# %%
main_df=pd.read_csv('main_df_cleared.csv')
main_df.head(1)
# Out:
#          Date  Brent  EUR_USD  Emerging_Markets    MOEXBC  RGBITR_YIELD  \
# 0  2019-08-28   60.5  1.10745         39.439999  18106.96          7.14
#
#    Russia_ETF  Treas_4M  USD_RUB  USD_Repo       VOL_USD  percent_change
# 0   21.870001      1.94     66.8      2.08  1.834422e+11        0.613774

# %%
main_df['MOEXBC_RusETF_Ratio']=main_df.MOEXBC/main_df.Russia_ETF 
main_df['Emerg_RusETF_Ratio']=main_df.Emerging_Markets/main_df.Russia_ETF
main_df['RGBITR_Treas_dif']=main_df.RGBITR_YIELD-main_df.Treas_4M
main_df.head(1)
# Out:
#          Date  Brent  EUR_USD  Emerging_Markets    MOEXBC  RGBITR_YIELD  \
# 0  2019-08-28   60.5  1.10745         39.439999  18106.96          7.14
#
#    Russia_ETF  Treas_4M  USD_RUB  USD_Repo       VOL_USD  percent_change  \
# 0   21.870001      1.94     66.8      2.08  1.834422e+11        0.613774
#
#    MOEXBC_RusETF_Ratio  Emerg_RusETF_Ratio  RGBITR_Treas_dif
# 0           827.935954            1.803383               5.2

# %%
abs(main_df.corr().USD_RUB).sort_values(ascending=False)
# Out:
# USD_RUB                1.000000
# MOEXBC_RusETF_Ratio    0.955370
# Treas_4M               0.869337
# MOEXBC                 0.703650
# USD_Repo               0.659734
# RGBITR_YIELD           0.551114
# Brent                  0.480552
# Emerg_RusETF_Ratio     0.448094
# RGBITR_Treas_dif       0.330005
# Emerging_Markets       0.319814
# EUR_USD                0.298211
# Russia_ETF             0.153380
# percent_change         0.066026
# VOL_USD                0.029323
# Name: USD_RUB, dtype: float64

# %%
main_df.drop(['VOL_USD','percent_change','Russia_ETF','EUR_USD','Emerging_Markets','Emerg_RusETF_Ratio','MOEXBC','RGBITR_YIELD','Treas_4M','USD_Repo'], 1,inplace=True)
main_df.head(1)
# Out:
#          Date  Brent  USD_RUB  MOEXBC_RusETF_Ratio  RGBITR_Treas_dif
# 0  2019-08-28   60.5     66.8           827.935954               5.2

# %% [markdown]
# ## Train/test split

# %%
test_df=main_df.drop('Date', 1)[:80] # the latest 80 trading days
train_df = main_df.drop('Date', 1)[80:]

# %% [markdown]
# ## Feature-wise normalisation

# %%
train_targets = train_df.USD_RUB.values
train_data=train_df.drop("USD_RUB", 1).values

test_targets = test_df.USD_RUB.values
test_data=test_df.drop("USD_RUB", 1).values

mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

test_data -= mean
test_data /= std

# %%
NAME = f"{BATCH_SIZE}-{opt}--{test_df.drop('USD_RUB', 1).columns.tolist()}--{int(time.time())}" 
tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
filepath = "regression-{epoch:02d}-{val_mean_absolute_error:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='max'))

# %% [markdown]
# ## Training DNN on cleaned dataset

# %%
model = Sequential()
model.add(Dense(128, activation='relu',input_shape=(train_data.shape[1],)))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(1))

model.compile(optimizer=opt, loss='mse', metrics=['mae'])

history = model.fit(
    train_data, train_targets,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(test_data, test_targets),
    callbacks=[tensorboard, checkpoint],
   )
# Out:
# Train on 505 samples, validate on 80 samples
# Epoch 1/150
# 505/505 [==============================] - 1s 2ms/sample - loss: 3661.3994 - mean_absolute_error: 60.4606 - val_loss: 3950.3715 - val_mean_absolute_error: 62.8452
# Epoch 2/150
# 505/505 [==============================] - 0s 511us/sample - loss: 3344.6275 - mean_absolute_error: 57.7691 - val_loss: 3555.9655 - val_mean_absolute_error: 59.6253
# Epoch 3/150
# 505/505 [==============================] - 0s 460us/sample - loss: 2898.8769 - mean_absolute_error: 53.7390 - val_loss: 2951.7418 - val_mean_absolute_error: 54.3255
# Epoch 4/150
# 505/505 [==============================] - 0s 466us/sample - loss: 2354.0621 - mean_absolute_error: 48.4055 - val_loss: 2267.4358 - val_mean_absolute_error: 47.6130
# Epoch 5/150
# 505/505 [==============================] - 0s 458us/sample - loss: 1761.6130 - mean_absolute_error: 41.7915 - val_loss: 1293.8217 - val_mean_absolute_error: 35.9314
# Epoch 6/150
# 505/505 [==============================] - 0s 458us/sample - loss: 1170.1179 - mean_absolute_error: 33.9403 - val_loss: 766.8743 - val_mean_absolute_error: 27.6724
# Epoch 7/150
# 505/505 [==============================] - 0s 470us/sample - loss: 643.2254 - mean_absolute_error: 24.9194 - val_loss: 300.6714 - val_mean_absolute_error: 17.2892
# Epoch 8/150
# 505/505 [==============================] - 0s 489us/sample - loss: 247.6550 - mean_absolute_error: 14.9140 - val_loss: 29.9444 - val_mean_absolute_error: 5.1399
# Epoch 9/150
# 505/505 [==============================] - 0s 452us/sample - loss: 49.7589 - mean_absolute_error: 5.7621 - val_loss: 9.8346 - val_mean_absolute_error: 2.7447
# Epoch 10/150
# 505/505 [==============================] - 0s 671us/sample - loss: 19.0248 - mean_absolute_error: 3.5190 - val_loss: 62.1505 - val_mean_absolute_error: 7.5522
# Epoch 11/150
# 505/505 [==============================] - 0s 456us/sample - loss: 16.1332 - mean_absolute_error: 3.2031 - val_loss: 17.1930 - val_mean_absolute_error: 3.9800
# Epoch 12/150
# 505/505 [==============================] - 0s 468us/sample - loss: 15.9587 - mean_absolute_error: 3.2174 - val_loss: 29.3459 - val_mean_absolute_error: 4.9208
# Epoch 13/150
# 505/505 [==============================] - 0s 472us/sample - loss: 16.5246 - mean_absolute_error: 3.1996 - val_loss: 3.9408 - val_mean_absolute_error: 1.6400
# Epoch 14/150
# 505/505 [==============================] - 0s 515us/sample - loss: 12.2962 - mean_absolute_error: 2.7927 - val_loss: 2.7159 - val_mean_absolute_error: 1.3271
# Epoch 15/150
# 505/505 [==============================] - 0s 573us/sample - loss: 13.0340 - mean_absolute_error: 2.8567 - val_loss: 5.2071 - val_mean_absolute_error: 1.9268
# Epoch 16/150
# 505/505 [==============================] - 0s 476us/sample - loss: 14.3442 - mean_absolute_error: 2.9347 - val_loss: 2.6450 - val_mean_absolute_error: 1.4065
# Epoch 17/150
# 505/505 [==============================] - 0s 476us/sample - loss: 12.5907 - mean_absolute_error: 2.8331 - val_loss: 2.7947 - val_mean_absolute_error: 1.4051
# Epoch 18/150
# 505/505 [==============================] - 0s 581us/sample - loss: 14.3743 - mean_absolute_error: 3.0227 - val_loss: 16.0372 - val_mean_absolute_error: 3.6877
# Epoch 19/150
# 505/505 [==============================] - 0s 573us/sample - loss: 12.0235 - mean_absolute_error: 2.7043 - val_loss: 2.0257 - val_mean_absolute_error: 1.2099
# Epoch 20/150
# 505/505 [==============================] - 0s 599us/sample - loss: 12.8071 - mean_absolute_error: 2.8135 - val_loss: 2.8076 - val_mean_absolute_error: 1.5122
# Epoch 21/150
# 505/505 [==============================] - 0s 478us/sample - loss: 11.9301 - mean_absolute_error: 2.7139 - val_loss: 10.6903 - val_mean_absolute_error: 3.0523
# Epoch 22/150
# 505/505 [==============================] - 0s 462us/sample - loss: 10.4215 - mean_absolute_error: 2.5831 - val_loss: 12.4848 - val_mean_absolute_error: 3.4260
# Epoch 23/150
# 505/505 [==============================] - 0s 522us/sample - loss: 11.3840 - mean_absolute_error: 2.6642 - val_loss: 3.5403 - val_mean_absolute_error: 1.5385
# Epoch 24/150
# 505/505 [==============================] - 0s 470us/sample - loss: 10.4516 - mean_absolute_error: 2.4939 - val_loss: 1.6660 - val_mean_absolute_error: 1.0773
# Epoch 25/150
# 505/505 [==============================] - 0s 458us/sample - loss: 10.8730 - mean_absolute_error: 2.6253 - val_loss: 4.0875 - val_mean_absolute_error: 1.7672
# Epoch 26/150
# 505/505 [==============================] - 0s 472us/sample - loss: 11.3005 - mean_absolute_error: 2.5924 - val_loss: 1.7894 - val_mean_absolute_error: 1.0233
# Epoch 27/150
# 505/505 [==============================] - 0s 452us/sample - loss: 10.6994 - mean_absolute_error: 2.5832 - val_loss: 3.0924 - val_mean_absolute_error: 1.5888
# Epoch 28/150
# 505/505 [==============================] - 0s 593us/sample - loss: 9.5638 - mean_absolute_error: 2.4761 - val_loss: 2.7325 - val_mean_absolute_error: 1.4855
# Epoch 29/150
# 505/505 [==============================] - 0s 583us/sample - loss: 9.0220 - mean_absolute_error: 2.3887 - val_loss: 2.9187 - val_mean_absolute_error: 1.4769
# Epoch 30/150
# 505/505 [==============================] - 0s 593us/sample - loss: 9.1867 - mean_absolute_error: 2.4106 - val_loss: 4.2412 - val_mean_absolute_error: 1.8481
# Epoch 31/150
# 505/505 [==============================] - 0s 480us/sample - loss: 8.6601 - mean_absolute_error: 2.3471 - val_loss: 4.9392 - val_mean_absolute_error: 2.1080
# Epoch 32/150
# 505/505 [==============================] - 0s 460us/sample - loss: 8.1472 - mean_absolute_error: 2.2305 - val_loss: 8.7219 - val_mean_absolute_error: 2.8093
# Epoch 33/150
# 505/505 [==============================] - 0s 590us/sample - loss: 9.8589 - mean_absolute_error: 2.4846 - val_loss: 8.9842 - val_mean_absolute_error: 2.8742
# Epoch 34/150
# 505/505 [==============================] - 0s 587us/sample - loss: 8.0643 - mean_absolute_error: 2.2739 - val_loss: 2.2744 - val_mean_absolute_error: 1.3168
# Epoch 35/150
# 505/505 [==============================] - 0s 608us/sample - loss: 8.1863 - mean_absolute_error: 2.2714 - val_loss: 0.9070 - val_mean_absolute_error: 0.7810
# Epoch 36/150
# 505/505 [==============================] - 0s 547us/sample - loss: 9.4152 - mean_absolute_error: 2.4228 - val_loss: 8.3063 - val_mean_absolute_error: 2.7751
# Epoch 37/150
# 505/505 [==============================] - 0s 482us/sample - loss: 9.2452 - mean_absolute_error: 2.3637 - val_loss: 0.8113 - val_mean_absolute_error: 0.7386
# Epoch 38/150
# 505/505 [==============================] - 0s 470us/sample - loss: 7.8343 - mean_absolute_error: 2.2104 - val_loss: 1.7588 - val_mean_absolute_error: 1.0624
# Epoch 39/150
# 505/505 [==============================] - 0s 474us/sample - loss: 7.1401 - mean_absolute_error: 2.1425 - val_loss: 0.8728 - val_mean_absolute_error: 0.8165
# Epoch 40/150
# 505/505 [==============================] - 0s 452us/sample - loss: 7.3088 - mean_absolute_error: 2.0766 - val_loss: 6.9243 - val_mean_absolute_error: 2.5263
# Epoch 41/150
# 505/505 [==============================] - 0s 474us/sample - loss: 7.6470 - mean_absolute_error: 2.1972 - val_loss: 0.7354 - val_mean_absolute_error: 0.7098
# Epoch 42/150
# 505/505 [==============================] - 0s 466us/sample - loss: 6.3661 - mean_absolute_error: 2.0005 - val_loss: 1.0149 - val_mean_absolute_error: 0.8433
# Epoch 43/150
# 505/505 [==============================] - 0s 474us/sample - loss: 6.8927 - mean_absolute_error: 2.1203 - val_loss: 0.8066 - val_mean_absolute_error: 0.7405
# Epoch 44/150
# 505/505 [==============================] - 0s 466us/sample - loss: 7.5510 - mean_absolute_error: 2.1924 - val_loss: 0.4272 - val_mean_absolute_error: 0.5099
# Epoch 45/150
# 505/505 [==============================] - 0s 464us/sample - loss: 6.8077 - mean_absolute_error: 2.0771 - val_loss: 0.6517 - val_mean_absolute_error: 0.6415
# Epoch 46/150
# 505/505 [==============================] - 0s 466us/sample - loss: 7.4536 - mean_absolute_error: 2.1911 - val_loss: 0.4383 - val_mean_absolute_error: 0.5298
# Epoch 47/150
# 505/505 [==============================] - 0s 456us/sample - loss: 7.2665 - mean_absolute_error: 2.1303 - val_loss: 0.4179 - val_mean_absolute_error: 0.5246
# Epoch 48/150
# 505/505 [==============================] - 0s 456us/sample - loss: 7.4086 - mean_absolute_error: 2.1268 - val_loss: 0.5725 - val_mean_absolute_error: 0.6373
# Epoch 49/150
# 505/505 [==============================] - 0s 424us/sample - loss: 6.5371 - mean_absolute_error: 2.0260 - val_loss: 0.8948 - val_mean_absolute_error: 0.7868
# Epoch 50/150
# 505/505 [==============================] - 0s 420us/sample - loss: 6.6698 - mean_absolute_error: 2.0261 - val_loss: 2.1295 - val_mean_absolute_error: 1.2718
# Epoch 51/150
# 505/505 [==============================] - 0s 462us/sample - loss: 6.3501 - mean_absolute_error: 2.0073 - val_loss: 0.5301 - val_mean_absolute_error: 0.5474
# Epoch 52/150
# 505/505 [==============================] - 0s 436us/sample - loss: 6.1253 - mean_absolute_error: 1.9407 - val_loss: 2.0585 - val_mean_absolute_error: 1.2691
# Epoch 53/150
# 505/505 [==============================] - 0s 513us/sample - loss: 5.9714 - mean_absolute_error: 1.9642 - val_loss: 3.9182 - val_mean_absolute_error: 1.8242
# Epoch 54/150
# 505/505 [==============================] - 0s 434us/sample - loss: 5.4052 - mean_absolute_error: 1.8504 - val_loss: 2.3254 - val_mean_absolute_error: 1.4242
# Epoch 55/150
# 505/505 [==============================] - 0s 438us/sample - loss: 5.5012 - mean_absolute_error: 1.8507 - val_loss: 0.8260 - val_mean_absolute_error: 0.7663
# Epoch 56/150
# 505/505 [==============================] - 0s 462us/sample - loss: 5.7389 - mean_absolute_error: 1.8868 - val_loss: 0.7936 - val_mean_absolute_error: 0.7343
# Epoch 57/150
# 505/505 [==============================] - 0s 499us/sample - loss: 4.1376 - mean_absolute_error: 1.6165 - val_loss: 2.3212 - val_mean_absolute_error: 1.3518
# Epoch 58/150
# 505/505 [==============================] - 0s 462us/sample - loss: 5.0173 - mean_absolute_error: 1.7946 - val_loss: 4.1452 - val_mean_absolute_error: 1.9395
# Epoch 59/150
# 505/505 [==============================] - 0s 454us/sample - loss: 5.1286 - mean_absolute_error: 1.8024 - val_loss: 0.4391 - val_mean_absolute_error: 0.5223
# Epoch 60/150
# 505/505 [==============================] - 0s 474us/sample - loss: 5.6057 - mean_absolute_error: 1.9081 - val_loss: 2.6691 - val_mean_absolute_error: 1.5293
# Epoch 61/150
# 505/505 [==============================] - 0s 468us/sample - loss: 6.0646 - mean_absolute_error: 1.9209 - val_loss: 0.9621 - val_mean_absolute_error: 0.7876
# Epoch 62/150
# 505/505 [==============================] - 0s 476us/sample - loss: 4.8454 - mean_absolute_error: 1.7444 - val_loss: 0.4558 - val_mean_absolute_error: 0.5241
# Epoch 63/150
# 505/505 [==============================] - 0s 470us/sample - loss: 4.3607 - mean_absolute_error: 1.6618 - val_loss: 1.8578 - val_mean_absolute_error: 1.1226
# Epoch 64/150
# 505/505 [==============================] - 0s 581us/sample - loss: 5.4158 - mean_absolute_error: 1.7957 - val_loss: 1.1960 - val_mean_absolute_error: 0.9175
# Epoch 65/150
# 505/505 [==============================] - 0s 537us/sample - loss: 4.5080 - mean_absolute_error: 1.7025 - val_loss: 0.7697 - val_mean_absolute_error: 0.7024
# Epoch 66/150
# 505/505 [==============================] - 0s 450us/sample - loss: 4.7649 - mean_absolute_error: 1.7673 - val_loss: 1.9587 - val_mean_absolute_error: 1.2276
# Epoch 67/150
# 505/505 [==============================] - 0s 450us/sample - loss: 5.7914 - mean_absolute_error: 1.8843 - val_loss: 0.5725 - val_mean_absolute_error: 0.5997
# Epoch 68/150
# 505/505 [==============================] - 0s 458us/sample - loss: 5.0046 - mean_absolute_error: 1.8074 - val_loss: 0.6930 - val_mean_absolute_error: 0.6460
# Epoch 69/150
# 505/505 [==============================] - 0s 454us/sample - loss: 4.5876 - mean_absolute_error: 1.7423 - val_loss: 2.1349 - val_mean_absolute_error: 1.2897
# Epoch 70/150
# 505/505 [==============================] - 0s 456us/sample - loss: 4.9118 - mean_absolute_error: 1.7426 - val_loss: 2.9934 - val_mean_absolute_error: 1.5389
# Epoch 71/150
# 505/505 [==============================] - 0s 523us/sample - loss: 5.3342 - mean_absolute_error: 1.8536 - val_loss: 1.1244 - val_mean_absolute_error: 0.8359
# Epoch 72/150
# 505/505 [==============================] - 0s 470us/sample - loss: 4.5307 - mean_absolute_error: 1.6838 - val_loss: 0.9082 - val_mean_absolute_error: 0.7485
# Epoch 73/150
# 505/505 [==============================] - 0s 458us/sample - loss: 4.5767 - mean_absolute_error: 1.7121 - val_loss: 0.3923 - val_mean_absolute_error: 0.4960
# Epoch 74/150
# 505/505 [==============================] - 0s 468us/sample - loss: 4.4391 - mean_absolute_error: 1.6570 - val_loss: 0.4531 - val_mean_absolute_error: 0.5108
# Epoch 75/150
# 505/505 [==============================] - 0s 499us/sample - loss: 4.5883 - mean_absolute_error: 1.6972 - val_loss: 1.6012 - val_mean_absolute_error: 1.1141
# Epoch 76/150
# 505/505 [==============================] - 0s 511us/sample - loss: 4.3511 - mean_absolute_error: 1.6408 - val_loss: 0.3741 - val_mean_absolute_error: 0.5086
# Epoch 77/150
# 505/505 [==============================] - 0s 466us/sample - loss: 4.6986 - mean_absolute_error: 1.7317 - val_loss: 4.0531 - val_mean_absolute_error: 1.9148
# Epoch 78/150
# 505/505 [==============================] - 0s 476us/sample - loss: 3.9875 - mean_absolute_error: 1.6006 - val_loss: 1.2813 - val_mean_absolute_error: 0.9733
# Epoch 79/150
# 505/505 [==============================] - 0s 450us/sample - loss: 3.9277 - mean_absolute_error: 1.5638 - val_loss: 0.6471 - val_mean_absolute_error: 0.6134
# Epoch 80/150
# 505/505 [==============================] - 0s 460us/sample - loss: 3.9159 - mean_absolute_error: 1.5561 - val_loss: 0.7710 - val_mean_absolute_error: 0.6785
# Epoch 81/150
# 505/505 [==============================] - 0s 458us/sample - loss: 4.0996 - mean_absolute_error: 1.6020 - val_loss: 0.3899 - val_mean_absolute_error: 0.5008
# Epoch 82/150
# 505/505 [==============================] - 0s 470us/sample - loss: 3.7544 - mean_absolute_error: 1.5904 - val_loss: 1.0824 - val_mean_absolute_error: 0.8544
# Epoch 83/150
# 505/505 [==============================] - 0s 470us/sample - loss: 4.0689 - mean_absolute_error: 1.6044 - val_loss: 0.7659 - val_mean_absolute_error: 0.7229
# Epoch 84/150
# 505/505 [==============================] - 0s 507us/sample - loss: 4.2562 - mean_absolute_error: 1.6432 - val_loss: 0.9994 - val_mean_absolute_error: 0.8454
# Epoch 85/150
# 505/505 [==============================] - 0s 507us/sample - loss: 4.1776 - mean_absolute_error: 1.5738 - val_loss: 0.8809 - val_mean_absolute_error: 0.7698
# Epoch 86/150
# 505/505 [==============================] - 0s 601us/sample - loss: 4.8053 - mean_absolute_error: 1.7227 - val_loss: 1.2574 - val_mean_absolute_error: 0.9507
# Epoch 87/150
# 505/505 [==============================] - 0s 482us/sample - loss: 4.2006 - mean_absolute_error: 1.6659 - val_loss: 1.6792 - val_mean_absolute_error: 1.1476
# Epoch 88/150
# 505/505 [==============================] - 0s 452us/sample - loss: 4.1098 - mean_absolute_error: 1.6614 - val_loss: 3.4571 - val_mean_absolute_error: 1.7769
# Epoch 89/150
# 505/505 [==============================] - 0s 487us/sample - loss: 3.9935 - mean_absolute_error: 1.5705 - val_loss: 1.0430 - val_mean_absolute_error: 0.8620
# Epoch 90/150
# 505/505 [==============================] - 0s 450us/sample - loss: 4.0449 - mean_absolute_error: 1.6172 - val_loss: 0.3384 - val_mean_absolute_error: 0.4795
# Epoch 91/150
# 505/505 [==============================] - 0s 458us/sample - loss: 3.5265 - mean_absolute_error: 1.4880 - val_loss: 0.6394 - val_mean_absolute_error: 0.6275
# Epoch 92/150
# 505/505 [==============================] - 0s 468us/sample - loss: 4.2876 - mean_absolute_error: 1.6976 - val_loss: 1.4775 - val_mean_absolute_error: 1.0808
# Epoch 93/150
# 505/505 [==============================] - 0s 458us/sample - loss: 4.8067 - mean_absolute_error: 1.7416 - val_loss: 2.7485 - val_mean_absolute_error: 1.5241
# Epoch 94/150
# 505/505 [==============================] - 0s 470us/sample - loss: 3.7330 - mean_absolute_error: 1.5571 - val_loss: 0.6225 - val_mean_absolute_error: 0.6231
# Epoch 95/150
# 505/505 [==============================] - 0s 472us/sample - loss: 3.6342 - mean_absolute_error: 1.5234 - val_loss: 0.7202 - val_mean_absolute_error: 0.6523
# Epoch 96/150
# 505/505 [==============================] - 0s 454us/sample - loss: 3.2651 - mean_absolute_error: 1.3937 - val_loss: 1.3728 - val_mean_absolute_error: 0.9774
# Epoch 97/150
# 505/505 [==============================] - 0s 676us/sample - loss: 3.8699 - mean_absolute_error: 1.5719 - val_loss: 0.4034 - val_mean_absolute_error: 0.4763
# Epoch 98/150
# 505/505 [==============================] - 0s 525us/sample - loss: 4.3257 - mean_absolute_error: 1.6962 - val_loss: 1.3623 - val_mean_absolute_error: 1.0095
# Epoch 99/150
# 505/505 [==============================] - 0s 531us/sample - loss: 3.9318 - mean_absolute_error: 1.5420 - val_loss: 0.7188 - val_mean_absolute_error: 0.6821
# Epoch 100/150
# 505/505 [==============================] - 0s 515us/sample - loss: 3.4263 - mean_absolute_error: 1.4143 - val_loss: 1.0565 - val_mean_absolute_error: 0.8577
# Epoch 101/150
# 505/505 [==============================] - 0s 515us/sample - loss: 4.2432 - mean_absolute_error: 1.5902 - val_loss: 0.6296 - val_mean_absolute_error: 0.6309
# Epoch 102/150
# 505/505 [==============================] - 0s 533us/sample - loss: 3.0934 - mean_absolute_error: 1.4230 - val_loss: 0.7224 - val_mean_absolute_error: 0.6897
# Epoch 103/150
# 505/505 [==============================] - 0s 456us/sample - loss: 3.3594 - mean_absolute_error: 1.4399 - val_loss: 0.6572 - val_mean_absolute_error: 0.6343
# Epoch 104/150
# 505/505 [==============================] - 0s 436us/sample - loss: 3.9615 - mean_absolute_error: 1.6037 - val_loss: 0.7258 - val_mean_absolute_error: 0.6681
# Epoch 105/150
# 505/505 [==============================] - 0s 458us/sample - loss: 5.0178 - mean_absolute_error: 1.7798 - val_loss: 1.2360 - val_mean_absolute_error: 0.9196
# Epoch 106/150
# 505/505 [==============================] - 0s 472us/sample - loss: 4.4642 - mean_absolute_error: 1.7367 - val_loss: 1.4971 - val_mean_absolute_error: 1.0146
# Epoch 107/150
# 505/505 [==============================] - 0s 454us/sample - loss: 3.5466 - mean_absolute_error: 1.5131 - val_loss: 1.3234 - val_mean_absolute_error: 0.9809
# Epoch 108/150
# 505/505 [==============================] - 0s 436us/sample - loss: 3.2165 - mean_absolute_error: 1.4206 - val_loss: 1.4500 - val_mean_absolute_error: 1.0593
# Epoch 109/150
# 505/505 [==============================] - 0s 434us/sample - loss: 3.9451 - mean_absolute_error: 1.5965 - val_loss: 1.2548 - val_mean_absolute_error: 0.9345
# Epoch 110/150
# 505/505 [==============================] - 0s 444us/sample - loss: 4.1649 - mean_absolute_error: 1.6010 - val_loss: 0.8302 - val_mean_absolute_error: 0.7550
# Epoch 111/150
# 505/505 [==============================] - ETA: 0s - loss: 4.0493 - mean_absolute_error: 1.6285- ETA: 0s - loss: 4.1892 - mean_absolute_error: 1.64 - 0s 450us/sample - loss: 3.8695 - mean_absolute_error: 1.5836 - val_loss: 0.5903 - val_mean_absolute_error: 0.6085
# Epoch 112/150
# 505/505 [==============================] - 0s 513us/sample - loss: 4.6335 - mean_absolute_error: 1.7177 - val_loss: 1.2317 - val_mean_absolute_error: 0.9574
# Epoch 113/150
# 505/505 [==============================] - 0s 450us/sample - loss: 3.7251 - mean_absolute_error: 1.5839 - val_loss: 1.3908 - val_mean_absolute_error: 1.0282
# Epoch 114/150
# 505/505 [==============================] - 0s 456us/sample - loss: 3.8229 - mean_absolute_error: 1.5470 - val_loss: 0.4337 - val_mean_absolute_error: 0.4922
# Epoch 115/150
# 505/505 [==============================] - 0s 456us/sample - loss: 4.0182 - mean_absolute_error: 1.6302 - val_loss: 1.1711 - val_mean_absolute_error: 0.9075
# Epoch 116/150
# 505/505 [==============================] - 0s 454us/sample - loss: 3.5465 - mean_absolute_error: 1.4560 - val_loss: 0.6858 - val_mean_absolute_error: 0.6512
# Epoch 117/150
# 505/505 [==============================] - 0s 454us/sample - loss: 3.5017 - mean_absolute_error: 1.4989 - val_loss: 0.4100 - val_mean_absolute_error: 0.5297
# Epoch 118/150
# 505/505 [==============================] - 0s 454us/sample - loss: 3.3320 - mean_absolute_error: 1.4687 - val_loss: 1.4128 - val_mean_absolute_error: 1.0226
# Epoch 119/150
# 505/505 [==============================] - 0s 589us/sample - loss: 3.3796 - mean_absolute_error: 1.4818 - val_loss: 0.3683 - val_mean_absolute_error: 0.4965
# Epoch 120/150
# 505/505 [==============================] - 0s 489us/sample - loss: 3.5296 - mean_absolute_error: 1.4958 - val_loss: 1.3935 - val_mean_absolute_error: 1.0148
# Epoch 121/150
# 505/505 [==============================] - 0s 482us/sample - loss: 3.1302 - mean_absolute_error: 1.4446 - val_loss: 0.4156 - val_mean_absolute_error: 0.5146
# Epoch 122/150
# 505/505 [==============================] - 0s 464us/sample - loss: 3.6468 - mean_absolute_error: 1.5343 - val_loss: 2.1824 - val_mean_absolute_error: 1.3569
# Epoch 123/150
# 505/505 [==============================] - 0s 478us/sample - loss: 2.8773 - mean_absolute_error: 1.3367 - val_loss: 0.8272 - val_mean_absolute_error: 0.7399
# Epoch 124/150
# 505/505 [==============================] - 0s 495us/sample - loss: 3.2709 - mean_absolute_error: 1.4682 - val_loss: 0.3256 - val_mean_absolute_error: 0.4681
# Epoch 125/150
# 505/505 [==============================] - 0s 460us/sample - loss: 4.0825 - mean_absolute_error: 1.6057 - val_loss: 0.8968 - val_mean_absolute_error: 0.8087
# Epoch 126/150
# 505/505 [==============================] - 0s 468us/sample - loss: 3.1788 - mean_absolute_error: 1.4466 - val_loss: 1.2754 - val_mean_absolute_error: 0.9673
# Epoch 127/150
# 505/505 [==============================] - 0s 478us/sample - loss: 3.4946 - mean_absolute_error: 1.4829 - val_loss: 0.8639 - val_mean_absolute_error: 0.7818
# Epoch 128/150
# 505/505 [==============================] - 0s 452us/sample - loss: 3.1639 - mean_absolute_error: 1.4059 - val_loss: 1.6167 - val_mean_absolute_error: 1.1298
# Epoch 129/150
# 505/505 [==============================] - 0s 495us/sample - loss: 3.7982 - mean_absolute_error: 1.5558 - val_loss: 1.9555 - val_mean_absolute_error: 1.2485
# Epoch 130/150
# 505/505 [==============================] - 0s 676us/sample - loss: 3.9330 - mean_absolute_error: 1.5861 - val_loss: 0.5765 - val_mean_absolute_error: 0.6140
# Epoch 131/150
# 505/505 [==============================] - 0s 511us/sample - loss: 2.9812 - mean_absolute_error: 1.3901 - val_loss: 1.3224 - val_mean_absolute_error: 0.9096
# Epoch 132/150
# 505/505 [==============================] - 0s 519us/sample - loss: 3.7206 - mean_absolute_error: 1.6050 - val_loss: 1.6275 - val_mean_absolute_error: 1.0968
# Epoch 133/150
# 505/505 [==============================] - 0s 490us/sample - loss: 4.0760 - mean_absolute_error: 1.5934 - val_loss: 0.6346 - val_mean_absolute_error: 0.6179
# Epoch 134/150
# 505/505 [==============================] - 0s 454us/sample - loss: 3.8771 - mean_absolute_error: 1.5448 - val_loss: 1.0262 - val_mean_absolute_error: 0.8330
# Epoch 135/150
# 505/505 [==============================] - 0s 619us/sample - loss: 3.5118 - mean_absolute_error: 1.4854 - val_loss: 1.9571 - val_mean_absolute_error: 1.2447
# Epoch 136/150
# 505/505 [==============================] - 0s 476us/sample - loss: 4.2930 - mean_absolute_error: 1.6351 - val_loss: 0.7051 - val_mean_absolute_error: 0.6585
# Epoch 137/150
# 505/505 [==============================] - 0s 466us/sample - loss: 3.3342 - mean_absolute_error: 1.4870 - val_loss: 0.7508 - val_mean_absolute_error: 0.7123
# Epoch 138/150
# 505/505 [==============================] - 0s 474us/sample - loss: 3.2145 - mean_absolute_error: 1.4105 - val_loss: 1.0436 - val_mean_absolute_error: 0.8376
# Epoch 139/150
# 505/505 [==============================] - 0s 438us/sample - loss: 3.7319 - mean_absolute_error: 1.5292 - val_loss: 0.8328 - val_mean_absolute_error: 0.7631
# Epoch 140/150
# 505/505 [==============================] - 0s 454us/sample - loss: 3.1501 - mean_absolute_error: 1.4223 - val_loss: 0.8482 - val_mean_absolute_error: 0.7435
# Epoch 141/150
# 505/505 [==============================] - 0s 458us/sample - loss: 3.3192 - mean_absolute_error: 1.4379 - val_loss: 2.0076 - val_mean_absolute_error: 1.2539
# Epoch 142/150
# 505/505 [==============================] - 0s 470us/sample - loss: 3.7699 - mean_absolute_error: 1.5803 - val_loss: 0.6341 - val_mean_absolute_error: 0.6213
# Epoch 143/150
# 505/505 [==============================] - 0s 448us/sample - loss: 3.0446 - mean_absolute_error: 1.4209 - val_loss: 1.1405 - val_mean_absolute_error: 0.9178
# Epoch 144/150
# 505/505 [==============================] - 0s 426us/sample - loss: 3.5487 - mean_absolute_error: 1.5458 - val_loss: 0.9588 - val_mean_absolute_error: 0.7800
# Epoch 145/150
# 505/505 [==============================] - 0s 418us/sample - loss: 3.6639 - mean_absolute_error: 1.5587 - val_loss: 1.7071 - val_mean_absolute_error: 1.0978
# Epoch 146/150
# 505/505 [==============================] - 0s 559us/sample - loss: 3.2844 - mean_absolute_error: 1.4295 - val_loss: 1.1557 - val_mean_absolute_error: 0.8888
# Epoch 147/150
# 505/505 [==============================] - 0s 468us/sample - loss: 3.5941 - mean_absolute_error: 1.4779 - val_loss: 2.1781 - val_mean_absolute_error: 1.3080
# Epoch 148/150
# 505/505 [==============================] - 0s 491us/sample - loss: 4.2425 - mean_absolute_error: 1.6354 - val_loss: 2.4059 - val_mean_absolute_error: 1.3395
# Epoch 149/150
# 505/505 [==============================] - 0s 466us/sample - loss: 4.4471 - mean_absolute_error: 1.7043 - val_loss: 1.4290 - val_mean_absolute_error: 1.0125
# Epoch 150/150
# 505/505 [==============================] - 0s 507us/sample - loss: 4.2311 - mean_absolute_error: 1.6938 - val_loss: 1.9936 - val_mean_absolute_error: 1.2552

# %% [markdown]
# ![alt text](222.png)

# %% [markdown]
# And this time the best result is (Brent, MOEXBC_RusETF_Ratio, RGBITR_Treas_dif) set of features.So Feature Engineering and data cleaning have reduced error and were helpful to improve our estimates.

# %% [markdown]
# ## Getting and normalizing features to predict on

# %%
predict_df=main_df
predict_df.sort_index(ascending=False,inplace=True)
predict_df.head(2)
# Out:
#            Date  Brent  USD_RUB  MOEXBC_RusETF_Ratio  RGBITR_Treas_dif
# 584  2017-03-14  51.56    59.16           727.973063             7.577
# 583  2017-03-15  51.97    58.39           703.163880             7.565

# %%
predict_data=predict_df.drop(["USD_RUB",'Date'], 1).values
predict_data-= mean
predict_data /= std

# %% [markdown]
# ## Some basic quantitative analysis of the results.

# %%
model = tf.keras.models.load_model("regression-144-0.546.model")# Load the most accurate model
prediction =  model.predict(predict_data,batch_size=1) # Predicting on all dataset
predict_df['prediction']=prediction
predict_df['deviation']=predict_df.USD_RUB-predict_df.prediction 
predict_df.head(2)
# Out:
#            Date  Brent  USD_RUB  MOEXBC_RusETF_Ratio  RGBITR_Treas_dif  \
# 584  2017-03-14  51.56    59.16           727.973063             7.577
# 583  2017-03-15  51.97    58.39           703.163880             7.565
#
#      prediction  deviation
# 584   58.052269   1.107731
# 583   55.870049   2.519951

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
                x=predict_df.Date,
                y=predict_df.USD_RUB,
                name="USD/RUB real value ",
                line_color='red',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=predict_df.Date,
                y=predict_df.prediction,
                name="USD/RUB 'fair' estimate",
                line_color='green',
                opacity=0.8))

fig.update_layout(title_text="USD/RUB values")
fig.show()
# Out:
# <div>
#
#
#             <div id="06e00ac9-b92f-4914-b67a-cf1387300ad9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("06e00ac9-b92f-4914-b67a-cf1387300ad9")) {
#                     Plotly.newPlot(
#                         '06e00ac9-b92f-4914-b67a-cf1387300ad9',
#                         [{"line": {"color": "red"}, "name": "USD/RUB real value ", "opacity": 0.8, "type": "scatter", "x": ["2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2018-01-04", "2018-01-05", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-12", "2018-02-13", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-02", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-09", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-19", "2018-03-20", "2018-03-21", "2018-03-22", "2018-03-23", "2018-03-26", "2018-03-27", "2018-03-28", "2018-03-29", "2018-04-02", "2018-04-03", "2018-04-04", "2018-04-05", "2018-04-06", "2018-04-11", "2018-04-12", "2018-04-13", "2018-04-17", "2018-04-18", "2018-04-19", "2018-04-20", "2018-04-23", "2018-04-24", "2018-04-25", "2018-04-26", "2018-04-27", "2018-04-30", "2018-05-02", "2018-05-03", "2018-05-04", "2018-05-07", "2018-05-08", "2018-05-10", "2018-05-11", "2018-05-14" ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
                x=predict_df.Date,
                y=predict_df.deviation,
                line_color='blue',
                opacity=0.8))
fig.update_layout(title_text="Deviation - difference between real and 'fair' values")
fig.show()
# Out:
# <div>
#
#
#             <div id="6769d0e1-8f6d-4845-a89e-e669b468dec3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6769d0e1-8f6d-4845-a89e-e669b468dec3")) {
#                     Plotly.newPlot(
#                         '6769d0e1-8f6d-4845-a89e-e669b468dec3',
#                         [{"line": {"color": "blue"}, "opacity": 0.8, "type": "scatter", "x": ["2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2018-01-04", "2018-01-05", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-12", "2018-02-13", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-02", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-09", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-19", "2018-03-20", "2018-03-21", "2018-03-22", "2018-03-23", "2018-03-26", "2018-03-27", "2018-03-28", "2018-03-29", "2018-04-02", "2018-04-03", "2018-04-04", "2018-04-05", "2018-04-06", "2018-04-11", "2018-04-12", "2018-04-13", "2018-04-17", "2018-04-18", "2018-04-19", "2018-04-20", "2018-04-23", "2018-04-24", "2018-04-25", "2018-04-26", "2018-04-27", "2018-04-30", "2018-05-02", "2018-05-03", "2018-05-04", "2018-05-07", "2018-05-08", "2018-05-10", "2018-05-11", "2018-05-14", "2018-05-15", "2018-05-16",  ...

# %%
fig = plt.figure(figsize=(16,6))
sns.distplot(predict_df.deviation, bins=12, fit=norm);

# %% [markdown]
# Unlike USD/RUB, prediction error has quite normal (Gaussian) distribution thus Empirical Rule can be applied.

# %% [markdown]
# ![alt text](Empirical_Rule.png)

# %% [markdown]
# The normal distribution is commonly associated with the 68-95-99.7 rule which you can see in the image above. 68% of the data is within 1 standard deviation (σ) of the mean (μ), 95% of the data is within 2 standard deviations (σ) of the mean (μ), and 99.7% of the data is within 3 standard deviations (σ) of the mean (μ).

# %%
USD_mean = round(predict_df.USD_RUB.mean(axis=0),2)
USD_std =round(predict_df.USD_RUB.std(axis=0),2)

mean_abs_error = round(float(abs(predict_df.deviation).mean(axis=0)),2)
mean_error = round(float(predict_df.deviation.mean(axis=0)),2)
std_deviation =  round(float(predict_df.deviation.std(axis=0)),2)
Relative_Mispricing=predict_df.deviation/std_deviation
predict_df['Upper_limit']=mean_error + 2*std_deviation
predict_df['Lower_limit']=mean_error - 2*std_deviation
predict_df['mean_error']=mean_error

print("USD mean value =", USD_mean) # calculated for the all cleaned dataset 
print("USD standard deviation =", USD_std) # calculated for the all cleaned dataset
print("Mean Error =",mean_error) # Mean Error of our prediction calculated for the all cleaned dataset
print("Mean Absolute Error =",mean_abs_error) # Mean Absolute Error of our prediction calculated for the all cleaned dataset 
print("Standard deviation of the error =", std_deviation) # standard deviation of  prediction error calculated for the all cleaned dataset
# Out:
# USD mean value = 61.83
# USD standard deviation = 3.83
# Mean Error = -0.07
# Mean Absolute Error = 0.55
# Standard deviation of the error = 0.74

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
                x=predict_df.Date,
                y=predict_df.deviation,
                name="deviation",
                line_color='blue',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=predict_df.Date,
                y=predict_df.mean_error+2*std_deviation,
                name="μ+2σ)",
                line_color='red',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=predict_df.Date,
                y=predict_df.mean_error+std_deviation,
                name="μ+σ)",
                line_color='coral',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=predict_df.Date,
                y=predict_df.mean_error-std_deviation,
                name="μ-σ)",
                line_color='olive',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=predict_df.Date,
                y=predict_df.mean_error-2*std_deviation,
                name="μ-2σ)",
                line_color='green',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=predict_df.Date,
                y=predict_df.mean_error,
                name="μ)",
                line_color='yellow',
                opacity=0.8))
              

fig.update_layout(title_text="Deviation values and μ ± σ limits ")
fig.show()
# Out:
# <div>
#
#
#             <div id="2dcecfb8-c188-4a34-9a5c-6f900b68e193" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2dcecfb8-c188-4a34-9a5c-6f900b68e193")) {
#                     Plotly.newPlot(
#                         '2dcecfb8-c188-4a34-9a5c-6f900b68e193',
#                         [{"line": {"color": "blue"}, "name": "deviation", "opacity": 0.8, "type": "scatter", "x": ["2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2018-01-04", "2018-01-05", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-12", "2018-02-13", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-02", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-09", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-19", "2018-03-20", "2018-03-21", "2018-03-22", "2018-03-23", "2018-03-26", "2018-03-27", "2018-03-28", "2018-03-29", "2018-04-02", "2018-04-03", "2018-04-04", "2018-04-05", "2018-04-06", "2018-04-11", "2018-04-12", "2018-04-13", "2018-04-17", "2018-04-18", "2018-04-19", "2018-04-20", "2018-04-23", "2018-04-24", "2018-04-25", "2018-04-26", "2018-04-27", "2018-04-30", "2018-05-02", "2018-05-03", "2018-05-04", "2018-05-07", "2018-05-08", "2018-05-10", "2018-05-11", "2018-05-14", "2018-0 ...

# %% [markdown]
# ## Wrapping up
# Quantitative analysis and statistical approach of assets pricing can be useful and give good results for the purposes of 'fair' baised on underlying fundamentals pricing as well as detection and evaluation of anomalys in market pricing. And even though fundamentals isn't always price movement's main driving force good understanding of them can give some adge.
